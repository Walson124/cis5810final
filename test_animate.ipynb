# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# %pip install diffusers transformers accelerate safetensors
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (2.2.2+cu118)
# Requirement already satisfied: torchvision in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (0.17.2)
# Requirement already satisfied: torchaudio in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (2.2.2+cu118)
# Requirement already satisfied: filelock in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torchvision) (10.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: diffusers in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (0.35.2)
# Requirement already satisfied: transformers in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (4.39.2)
# Requirement already satisfied: accelerate in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (1.10.1)
# Requirement already satisfied: safetensors in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (0.6.2)
# Requirement already satisfied: importlib_metadata in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (3.13.3)
# Requirement already satisfied: huggingface-hub>=0.34.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (0.35.3)
# Requirement already satisfied: numpy in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (2.31.0)
# Requirement already satisfied: Pillow in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from diffusers) (10.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\walson\appdata\roaming\python\python312\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: psutil in c:\users\walson\appdata\roaming\python\python312\site-packages (from accelerate) (5.9.8)
# Requirement already satisfied: torch>=2.0.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from accelerate) (2.2.2+cu118)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.34.0->diffusers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from huggingface-hub>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: sympy in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch>=2.0.0->accelerate) (1.12)
# Requirement already satisfied: networkx in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch>=2.0.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from torch>=2.0.0->accelerate) (3.1.3)
# Requirement already satisfied: colorama in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from requests->diffusers) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\walson\anaconda3\envs\myenv\lib\site-packages (from sympy->torch>=2.0.0->accelerate) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\grpcio-1.62.1.dist-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from diffusers import StableDiffusionPipeline
from diffusers import StableDiffusionPipeline
from PIL import Image
import os
import subprocess

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
).to("cuda")  # or "cpu" if no GPU
# Out:
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Walson\.cache\huggingface\hub\models--runwayml--stable-diffusion-v1-5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# config.json: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# vocab.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 4
#       1 pipe = StableDiffusionPipeline.from_pretrained(
#       2     "runwayml/stable-diffusion-v1-5",
#       3     torch_dtype=torch.float16
# ----> 4 ).to("cuda")  # or "cpu" if no GPU
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\diffusers\pipelines\pipeline_utils.py:541, in DiffusionPipeline.to(self, *args, **kwargs)
#     539     module.to(device=device)
#     540 elif not is_loaded_in_4bit_bnb and not is_loaded_in_8bit_bnb and not is_group_offloaded:
# --> 541     module.to(device, dtype)
#     543 if (
#     544     module.dtype == torch.float16
#     545     and str(device) in ["cpu"]
#     546     and not silence_dtype_warnings
#     547     and not is_offloaded
#     548 ):
#     549     logger.warning(
#     550         "Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It"
#     551         " is not recommended to move them to `cpu` as running them will fail. Please make"
#    (...)
#     554         " `torch_dtype=torch.float16` argument, or use another device for inference."
#     555     )
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\transformers\modeling_utils.py:2576, in PreTrainedModel.to(self, *args, **kwargs)
#    2571     if dtype_present_in_args:
#    2572         raise ValueError(
#    2573             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2574             " `dtype` by passing the correct `torch_dtype` argument."
#    2575         )
# -> 2576 return super().to(*args, **kwargs)
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1152, in Module.to(self, *args, **kwargs)
#    1148         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                     non_blocking, memory_format=convert_to_format)
#    1150     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1152 return self._apply(convert)
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 802 (1 times)]
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:802, in Module._apply(self, fn, recurse)
#     800 if recurse:
#     801     for module in self.children():
# --> 802         module._apply(fn)
#     804 def compute_should_use_set_data(tensor, tensor_applied):
#     805     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     806         # If the new tensor has compatible tensor type as the existing tensor,
#     807         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     812         # global flag to let the user control whether they want the future
#     813         # behavior of overwriting the existing tensor or not.
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:825, in Module._apply(self, fn, recurse)
#     821 # Tensors stored in modules are graph leaves, and we don't want to
#     822 # track autograd history of `param_applied`, so we have to use
#     823 # `with torch.no_grad():`
#     824 with torch.no_grad():
# --> 825     param_applied = fn(param)
#     826 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     827 if should_use_set_data:
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1150, in Module.to.<locals>.convert(t)
#    1147 if convert_to_format is not None and t.dim() in (4, 5):
#    1148     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1149                 non_blocking, memory_format=convert_to_format)
# -> 1150 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# File c:\Users\Walson\anaconda3\envs\myenv\Lib\site-packages\torch\cuda\__init__.py:302, in _lazy_init()
#     300 if "CUDA_MODULE_LOADING" not in os.environ:
#     301     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 302 torch._C._cuda_init()
#     303 # Some of the queued calls may reentrantly call _lazy_init();
#     304 # we need to just return without initializing in that case.
#     305 # However, we must not let any *other* threads in!
#     306 _tls.is_initializing = True
#
# RuntimeError: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx

# %%
prompt = "A teacup dancing on a table"
image = pipe(prompt).images[0]
image.save("frame_000.png")

# %%
# %ffmpeg -framerate 5 -i frame_%03d.png -c:v libx264 -pix_fmt yuv420p output.mp4
